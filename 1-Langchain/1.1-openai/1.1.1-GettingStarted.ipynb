# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x000001DA0CA71BA0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001DA26402B60> root_client=<openai.OpenAI object at 0x000001DA25DAFFA0> root_async_client=<openai.AsyncOpenAI object at 0x000001DA26402AD0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********')

# %%
## Input and get response form LLM

result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a category of artificial intelligence models and systems designed to generate new content. Unlike traditional AI, which is primarily focused on analyzing data or recognizing patterns, generative AI creates new data that resembles the data it was trained on. This can include text, images, audio, and more.\n\nGenerative AI typically involves models such as Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and transformers. These models can learn from vast datasets to produce new outputs that maintain coherence and similarity to the training data.\n\nApplications of generative AI are broad and varied, encompassing areas such as:\n\n1. **Text Generation**: Producing human-like text for applications like chatbots, content creation, and translation. GPT-3 and ChatGPT are examples.\n2. **Image and Video Creation**: Generating realistic images or deepfakes, designing art, and enhancing video quality.\n3. **Music and Audio**: Composing original music and generating realistic or synthetic sounds.\n4. **Design and Prototyping**: Assisting in product design and architectural planning by generating various design alternatives.\n5. **Drug Discovery**: Designing new molecules for pharmaceutical research.\n\nGenerative AI has significant potential but also raises ethical considerations, such as the potential for misuse in generating misleading or harmful content.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 269, 'prompt_tokens': 13, 'total_tokens': 282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CFv6FQopRTJTzJmTaUNusHzNuKAx5', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--7528bac2-84e9-40ed-9736-c0cfb05b2c15-0' usage_metadata={'input_tokens': 13, 'output_tokens': 269, 'total_tokens': 282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content="Langsmith is a toolset developed by the team behind LangChain, designed to aid developers in building applications with language models. It focuses on the orchestration and management of large language models (LLMs) and offers capabilities for testing, tracing, debugging, evaluating, and monitoring production LLM applications. Langsmith's core features allow developers to experiment with different model configurations, evaluate model performance using custom metrics, and effectively trace the interactions between applications and LLMs for better debugging and optimization. It supports tracking performance across multiple dimensions, such as latency and cost, and is designed to seamlessly integrate with existing LangChain applications, enhancing their reliability and efficiency." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 130, 'prompt_tokens': 33, 'total_tokens': 163, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CFvDNGhbKIcGh01EVIVgfItZTMgJy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--1443ee0c-abc4-47c4-8ef0-342750cdef65-0' usage_metadata={'input_tokens': 33, 'output_tokens': 130, 'total_tokens': 163, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a toolset developed for enhancing the development experience with large language models (LLMs). It offers features for tracing, debugging, and testing LLM applications, which makes it particularly valuable for developers who are building complex AI-driven applications. Langsmith is integrated with LangChain, a popular framework for creating apps with LLMs, allowing seamless debugging and monitoring of LLM workflows.
#
# The primary capabilities of Langsmith include:
# - **Tracing**: This feature helps developers track and record the execution of their LLM applications, making it easier to understand how data flows through different stages and where potential issues may arise.
# - **Debugging**: Developers can utilize Langsmith to pinpoint and resolve errors or suboptimal performance within their LLM-centric applications.
# - **Testing**: Langsmith provides tools to create and run tests to ensure the robustness and accuracy of LLM applications.
#
# Overall, Langsmith simplifies the process of building AI applications by offering necessary insights and diagnostics, ultimately resulting in more reliable and effective LLM solutions.
